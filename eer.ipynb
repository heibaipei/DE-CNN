# %%
 import pandas as pd
 excel_path = 'example.xlsx'
 d = pd.read_excel(excel_path, sheetname=None)
 print(d['sheet1'].example_column_name)
# Out:
# 0.00020466639377814163

# %%
from scipy import interpolate
from scipy.optimize import brentq

import matplotlib.pyplot as plt

# %matplotlib inline 

far = [1.0, 0.0057306590257879654, 0.005116659844453541, 0.004911993450675399, 0.004707327056897258, 0.004707327056897258, 0.004297994269340974, 0.004297994269340974, 0.004297994269340974, 0.004297994269340974, 0.004297994269340974, 0.004093327875562832, 0.004093327875562832, 0.004093327875562832, 0.003888661481784691, 0.003888661481784691, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0036839950880065493, 0.0034793286942284077, 0.0034793286942284077, 0.0034793286942284077, 0.003274662300450266, 0.003274662300450266, 0.003274662300450266, 0.003274662300450266, 0.003274662300450266, 0.003274662300450266, 0.003274662300450266, 0.003274662300450266, 0.003274662300450266, 0.0030699959066721244, 0.0030699959066721244, 0.0030699959066721244, 0.0030699959066721244, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.0028653295128939827, 0.002660663119115841, 0.0022513303315595578]
frr = [0.0, 0.034383954154727794, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04011461318051576, 0.04297994269340974, 0.04297994269340974, 0.04297994269340974, 0.04297994269340974, 0.045845272206303724, 0.045845272206303724, 0.045845272206303724, 0.045845272206303724, 0.045845272206303724, 0.045845272206303724, 0.045845272206303724, 0.045845272206303724, 0.045845272206303724, 0.04871060171919771, 0.04871060171919771, 0.04871060171919771, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.05157593123209169, 0.054441260744985676, 0.054441260744985676, 0.054441260744985676, 0.054441260744985676, 0.054441260744985676, 0.05730659025787966, 0.05730659025787966, 0.05730659025787966, 0.06017191977077364, 0.06017191977077364, 0.06017191977077364, 0.06017191977077364, 0.06017191977077364, 0.0659025787965616, 0.0659025787965616, 0.0659025787965616, 0.06876790830945559, 0.07736389684813753]
plt.figure()
plt.plot(far, frr, color = 'green', marker = 'o',label = 'ROC')
plt.legend()
plt.xlim([0,1.25])
plt.ylim([0,1.25])
plt.xlabel('far')
plt.ylabel('trr')
plt.title('ROC')
plt.show()

root = brentq(lambda x: x - interpolate.interp1d(frr, far)(x), 0, max(frr))
print(root)
# Out:
# 0.033426183844011144
